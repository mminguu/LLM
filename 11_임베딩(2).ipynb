# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in ./.venv/lib/python3.13/site-packages (3.9.2)
# Requirement already satisfied: click in ./.venv/lib/python3.13/site-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in ./.venv/lib/python3.13/site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.13/site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.13/site-packages (from nltk) (4.67.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import (
    Embedding, Dense, SimpleRNN, LSTM, Bidirectional, Flatten
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from nltk.corpus import movie_reviews
from sklearn.model_selection import train_test_split
# Out:
# [nltk_data] Downloading package punkt to /Users/kangminji/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kangminji/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/kangminji/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# 1 .데이터 로드
ids = movie_reviews.fileids()
reviews = [movie_reviews.raw(id) for id in ids]
categoris = [movie_reviews.categories(id)[0] for id in ids]
# 토큰화 및 정수 인코딩
max_word = 10000
tokenizer = Tokenizer(num_words=max_word, oov_token='UNK')
tokenizer.fit_on_texts(reviews)
# 텍스트를 시퀀스로 변환
x = tokenizer.texts_to_sequences(reviews)
# 시퀀스 패딩
maxlen = 500
x = pad_sequences(x,maxlen=maxlen,truncating='pre')
# 레이블 변환
label_dict = {'pos':1, 'neg':0}
y = np.array([label_dict[c] for c in categoris])
# 학습 테스트 데이터 분할
x_train,x_test,y_train,y_test = train_test_split(x,y,stratify=y, random_state=42,test_size=0.2)

# %%
# 2 .세가지 모델 구축 , 학습
# 시드 고정 (재현성)

np.random.seed(42)
tf.random.set_seed(42)
# 모델 성능
results = {}
# ------ model 1 baseline(Flatten + Dense)
model1 = Sequential([
    Embedding(max_word,32,input_length = maxlen),
    Flatten(),
    Dense(1,activation='sigmoid')
])
model1.compile(optimizer = 'adam', loss = 'binary_crossentropy',metrics=['acc'])
model1.fit(x_train,y_train,epochs=10,batch_size=32,validation_split=0.2)
score1 = model1.evaluate(x_test,y_test)
results['baseline'] = score1[1]
print(f'model1 정확도:{score1[1]:.4f}')


# ------ model 2 SimpleRnn
model2 = Sequential([
    Embedding(max_word,32,input_length = maxlen),
    SimpleRNN(32),
    Dense(32,activation='relu'),
    Dense(1,activation='sigmoid')
])
model2.compile(optimizer = 'adam', loss = 'binary_crossentropy',metrics=['acc'])
model2.fit(x_train,y_train,epochs=10,batch_size=32,validation_split=0.2)
score1 = model2.evaluate(x_test,y_test)
results['Simple_RNN'] = score1[1]
print(f'model2 정확도:{score1[1]:.4f}')

# ------ model 3 (Bidirectional LSTM)
model3 = Sequential([
    Embedding(max_word,64,input_length = maxlen),
    Bidirectional(LSTM(64)),    
    Dense(64,activation='relu'),
    Dense(1,activation='sigmoid')
])
model3.compile(optimizer = 'adam', loss = 'binary_crossentropy',metrics=['acc'])
history3 = model3.fit(x_train,y_train,epochs=10,batch_size=32,validation_split=0.2)
score1 = model3.evaluate(x_test,y_test)
results['Bidirectional_LSTM'] = score1[1]
print(f'model3 정확도:{score1[1]:.4f}')
# Out:
# Epoch 1/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5156 - loss: 0.6919 - val_acc: 0.5813 - val_loss: 0.6910
# Epoch 2/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9812 - loss: 0.5898 - val_acc: 0.5625 - val_loss: 0.6857
# Epoch 3/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9805 - loss: 0.4427 - val_acc: 0.6250 - val_loss: 0.6731
# Epoch 4/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.9961 - loss: 0.2658 - val_acc: 0.6313 - val_loss: 0.6596
# Epoch 5/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.1385 - val_acc: 0.6344 - val_loss: 0.6496
# Epoch 6/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0754 - val_acc: 0.6500 - val_loss: 0.6450
# Epoch 7/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0455 - val_acc: 0.6375 - val_loss: 0.6426
# Epoch 8/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0301 - val_acc: 0.6406 - val_loss: 0.6409
# Epoch 9/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0215 - val_acc: 0.6500 - val_loss: 0.6399
# Epoch 10/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0161 - val_acc: 0.6500 - val_loss: 0.6396
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - acc: 0.6575 - loss: 0.6258
# model1 정확도:0.6575
# Epoch 1/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - acc: 0.5078 - loss: 0.6976 - val_acc: 0.5437 - val_loss: 0.6893
# Epoch 2/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - acc: 0.5492 - loss: 0.6878 - val_acc: 0.5406 - val_loss: 0.6876
# Epoch 3/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - acc: 0.6883 - loss: 0.6321 - val_acc: 0.4875 - val_loss: 0.7114
# Epoch 4/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - acc: 0.9563 - loss: 0.3659 - val_acc: 0.5219 - val_loss: 0.9023
# Epoch 5/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - acc: 0.9867 - loss: 0.1222 - val_acc: 0.4906 - val_loss: 0.9239
# Epoch 6/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - acc: 0.9930 - loss: 0.0443 - val_acc: 0.4969 - val_loss: 0.9972
# Epoch 7/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - acc: 0.9969 - loss: 0.0211 - val_acc: 0.5063 - val_loss: 1.1356
# Epoch 8/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - acc: 0.9984 - loss: 0.0112 - val_acc: 0.5031 - val_loss: 1.2005
# Epoch 9/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - acc: 0.9992 - loss: 0.0067 - val_acc: 0.5094 - val_loss: 1.2478
# Epoch 10/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - acc: 0.9992 - loss: 0.0040 - val_acc: 0.4781 - val_loss: 1.3223
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acc: 0.5225 - loss: 1.2635
# model2 정확도:0.5225
# Epoch 1/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - acc: 0.5148 - loss: 0.6936 - val_acc: 0.5406 - val_loss: 0.6911
# Epoch 2/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - acc: 0.6422 - loss: 0.6597 - val_acc: 0.6562 - val_loss: 0.6289
# Epoch 3/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - acc: 0.8664 - loss: 0.3517 - val_acc: 0.6906 - val_loss: 0.6493
# Epoch 4/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - acc: 0.9609 - loss: 0.1197 - val_acc: 0.6719 - val_loss: 0.9962
# Epoch 5/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - acc: 0.9805 - loss: 0.0560 - val_acc: 0.6625 - val_loss: 1.6889
# Epoch 6/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - acc: 0.9750 - loss: 0.0743 - val_acc: 0.7375 - val_loss: 0.9477
# Epoch 7/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - acc: 0.9586 - loss: 0.1039 - val_acc: 0.6781 - val_loss: 0.8569
# Epoch 8/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - acc: 0.9961 - loss: 0.0171 - val_acc: 0.7625 - val_loss: 1.0028
# Epoch 9/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - acc: 0.9992 - loss: 0.0099 - val_acc: 0.7437 - val_loss: 1.1251
# Epoch 10/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - acc: 0.9992 - loss: 0.0047 - val_acc: 0.7750 - val_loss: 1.2205
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.7200 - loss: 1.3969
# model3 정확도:0.7200

# %%
# 3 .성능 비교 및 시각화

# %%
# 4 .예측 결과 분석

# %%
# 5 .학습결과 해석
